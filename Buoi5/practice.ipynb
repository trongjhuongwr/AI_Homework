# %%
text = "Lãnh thổ Việt Nam xuất hiện con người sinh sống từ thời đại đồ đá cũ, khởi đầu với các nhà nước Văn Lang, Âu Lạc. Âu Lạc bị nhà Triệu ở phương Bắc thôn tính vào đầu thế kỷ thứ 2 TCN sau đó là thời kỳ Bắc thuộc kéo dài hơn một thiên niên kỷ. Chế độ quân chủ độc lập được tái lập sau chiến thắng của Ngô Quyền trước nhà Nam Hán, mở đường cho các triều đại độc lập kế tục, nhiều lần chiến thắng trước các cuộc chiến tranh xâm lược từ phương Bắc đồng thời dần mở rộng về phía nam. Thời kỳ Bắc thuộc cuối cùng kết thúc sau chiến thắng trước nhà Minh của nghĩa quân Lam Sơn."

# %%
def Split_Sentences(text):
    Sentences = []
    current_sentence = ""
    
    for char in text:
        current_sentence += char
        if char in ['.', '!', '?']:
            next_index = text.index(char) + 1
            if next_index < len(text) and text[next_index].isspace():
                Sentences.append(current_sentence.strip())
                current_sentence = ""
    if current_sentence:
        Sentences.append(current_sentence.strip())
    return Sentences

result = Split_Sentences(text)
for i, sentence in enumerate(result, 1):
    print(f"Câu {i}: {sentence}")
# Out:
# Câu 1: Lãnh thổ Việt Nam xuất hiện con người sinh sống từ thời đại đồ đá cũ, khởi đầu với các nhà nước Văn Lang, Âu Lạc.
# Câu 2: Âu Lạc bị nhà Triệu ở phương Bắc thôn tính vào đầu thế kỷ thứ 2 TCN sau đó là thời kỳ Bắc thuộc kéo dài hơn một thiên niên kỷ.
# Câu 3: Chế độ quân chủ độc lập được tái lập sau chiến thắng của Ngô Quyền trước nhà Nam Hán, mở đường cho các triều đại độc lập kế tục, nhiều lần chiến thắng trước các cuộc chiến tranh xâm lược từ phương Bắc đồng thời dần mở rộng về phía nam.
# Câu 4: Thời kỳ Bắc thuộc cuối cùng kết thúc sau chiến thắng trước nhà Minh của nghĩa quân Lam Sơn.

# %%
def Split_Word(text):
    Words = []
    current_word = ""

    for char in text:
        if char.isalnum():
              current_word += char
        else:
            if current_word:
                Words.append(current_word)
                current_word = ""
    if current_word:
        Words.append(current_word)
    return Words

result = Split_Word(text)
for i, word in enumerate(result, 1):
    print(f"{i}. {word}")
# Out:
# 1. Lãnh
# 2. thổ
# 3. Việt
# 4. Nam
# 5. xuất
# 6. hiện
# 7. con
# 8. người
# 9. sinh
# 10. sống
# 11. từ
# 12. thời
# 13. đại
# 14. đồ
# 15. đá
# 16. cũ
# 17. khởi
# 18. đầu
# 19. với
# 20. các
# 21. nhà
# 22. nước
# 23. Văn
# 24. Lang
# 25. Âu
# 26. Lạc
# 27. Âu
# 28. Lạc
# 29. bị
# 30. nhà
# 31. Triệu
# 32. ở
# 33. phương
# 34. Bắc
# 35. thôn
# 36. tính
# 37. vào
# 38. đầu
# 39. thế
# 40. kỷ
# 41. thứ
# 42. 2
# 43. TCN
# 44. sau
# 45. đó
# 46. là
# 47. thời
# 48. kỳ
# 49. Bắc
# 50. thuộc
# 51. kéo
# 52. dài
# 53. hơn
# 54. một
# 55. thiên
# 56. niên
# 57. kỷ
# 58. Chế
# 59. độ
# 60. quân
# 61. chủ
# 62. độc
# 63. lập
# 64. được
# 65. tái
# 66. lập
# 67. sau
# 68. chiến
# 69. thắng
# 70. của
# 71. Ngô
# 72. Quyền
# 73. trước
# 74. nhà
# 75. Nam
# 76. Hán
# 77. mở
# 78. đường
# 79. cho
# 80. các
# 81. triều
# 82. đại
# 83. độc
# 84. lập
# 85. kế
# 86. tục
# 87. nhiều
# 88. lần
# 89. chiến
# 90. thắng
# 91. trước
# 92. các
# 93. cuộc
# 94. chiến
# 95. tranh
# 96. xâm
# 97. lược
# 98. từ
# 99. phương
# 100. Bắc
# 101. đồng
# 102. thời
# 103. dần
# 104. mở
# 105. rộng
# 106. về
# 107. phía
# 108. nam
# 109. Thời
# 110. kỳ
# 111. Bắc
# 112. thuộc
# 113. cuối
# 114. cùng
# 115. kết
# 116. thúc
# 117. sau
# 118. chiến
# 119. thắng
# 120. trước
# 121. nhà
# 122. Minh
# 123. của
# 124. nghĩa
# 125. quân
# 126. Lam
# 127. Sơn

# %%
words_count = {}
def count_words(text):
    Words = Split_Word(text)
    word_count = {}
    for word in Words:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1
    words_count.update(word_count)
    return word_count
result = count_words(text)
for word, count in result.items():
    print(f"{str(word)}: {str(count)} lần")
# Out:
# Lãnh: 1 lần
# thổ: 1 lần
# Việt: 1 lần
# Nam: 2 lần
# xuất: 1 lần
# hiện: 1 lần
# con: 1 lần
# người: 1 lần
# sinh: 1 lần
# sống: 1 lần
# từ: 2 lần
# thời: 3 lần
# đại: 2 lần
# đồ: 1 lần
# đá: 1 lần
# cũ: 1 lần
# khởi: 1 lần
# đầu: 2 lần
# với: 1 lần
# các: 3 lần
# nhà: 4 lần
# nước: 1 lần
# Văn: 1 lần
# Lang: 1 lần
# Âu: 2 lần
# Lạc: 2 lần
# bị: 1 lần
# Triệu: 1 lần
# ở: 1 lần
# phương: 2 lần
# Bắc: 4 lần
# thôn: 1 lần
# tính: 1 lần
# vào: 1 lần
# thế: 1 lần
# kỷ: 2 lần
# thứ: 1 lần
# 2: 1 lần
# TCN: 1 lần
# sau: 3 lần
# đó: 1 lần
# là: 1 lần
# kỳ: 2 lần
# thuộc: 2 lần
# kéo: 1 lần
# dài: 1 lần
# hơn: 1 lần
# một: 1 lần
# thiên: 1 lần
# niên: 1 lần
# Chế: 1 lần
# độ: 1 lần
# quân: 2 lần
# chủ: 1 lần
# độc: 2 lần
# lập: 3 lần
# được: 1 lần
# tái: 1 lần
# chiến: 4 lần
# thắng: 3 lần
# của: 2 lần
# Ngô: 1 lần
# Quyền: 1 lần
# trước: 3 lần
# Hán: 1 lần
# mở: 2 lần
# đường: 1 lần
# cho: 1 lần
# triều: 1 lần
# kế: 1 lần
# tục: 1 lần
# nhiều: 1 lần
# lần: 1 lần
# cuộc: 1 lần
# tranh: 1 lần
# xâm: 1 lần
# lược: 1 lần
# đồng: 1 lần
# dần: 1 lần
# rộng: 1 lần
# về: 1 lần
# phía: 1 lần
# nam: 1 lần
# Thời: 1 lần
# cuối: 1 lần
# cùng: 1 lần
# kết: 1 lần
# thúc: 1 lần
# Minh: 1 lần
# nghĩa: 1 lần
# Lam: 1 lần
# Sơn: 1 lần

# %%
import matplotlib.pyplot as plt
import numpy as np

x = dict.keys(words_count)
y = dict.values(words_count)

plt.figure(figsize=(50, 20))
plt.plot(x, y)
plt.show()
